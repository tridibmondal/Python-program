# %%
print("*******Bank Management System********")

print("------Main menu-------")

bank_data={}
user_data={}

while True:
	ch=int(input("""
		1.New Customer 
		2.Existing Customer
		3.Exit 
        Enter choice :"""))
	if(ch==1):
		name=input("enter the name :")
		city=input("enter the city :")
		age=int(input("enter the age:"))
		acc_type=input("enter account type :")
		amt=int(input("enter intial amount :"))
		acc_no=int(input("enter the account no"))


		user_data["name"] = name
		user_data["city"] = city
		user_data["age"] = age
		user_data["acc_type"] = acc_type
		user_data["amount"] = amt

		bank_data["account_number"] = acc_no
		bank_data["detail"] =user_data

		print("\n -----Account created Successfully----")

	elif(ch==2):
		acc_no=int(input("enter account number"))

		if acc_no==bank_data["account_number"]:
			print("\n-------Account Exists--------")

			while True:
				print("\t\t-----User Portal------")

				u_ch=int(input("\n1.check Balance\n2.Withdrwa\n3.Deposit\n4.Back to main menu\n\nEnter choice:"))

				if(u_ch==1):
					print("your avaliable balance:",bank_data["detail"]["amount"])
				
				elif(u_ch==2):
					w_amt=int(input("enter the amount to be Withdraw :"))
					bank_data["detail"]["amount"]=bank_data["detail"]["amount"]-w_amt
					print("Amount Withdrawn")
				
				elif(u_ch==3):
					d_amt=int(input("enter the amount to be deposited :"))
					bank_data["detail"]["amount"]=bank_data["detail"]["amount"]+d_amt
					print("\n-----Amount deposited-----")

				elif(u_ch==4):
					break

				else:
					print("\nInvalid Input")

		else:
			print("-----Account does not exist------")

	elif(ch==3):
		break

	else:
		print("\nInvalid Input")
# Out:
# *******Bank Management System********
# ------Main menu-------
#
# 		1.New Customer
# 		2.Existing Customer
# 		3.Exit
#         Enter choice :1
# enter the name :tridib
# enter the city :dgp
# enter the age:19
# enter account type :s
# enter intial amount :100000
# enter the account no1
#
#  -----Account created Successfully----
#
# 		1.New Customer
# 		2.Existing Customer
# 		3.Exit
#         Enter choice :1
# enter the name :sunny
# enter the city :dgp
# enter the age:19
# enter account type :s
# enter intial amount :10000
# enter the account no1
#
#  -----Account created Successfully----
#
# 		1.New Customer
# 		2.Existing Customer
# 		3.Exit
#         Enter choice :2
# enter account number2
# -----Account does not exist------
#
# 		1.New Customer
# 		2.Existing Customer
# 		3.Exit
#         Enter choice :1
# enter the name :Tathagata
# enter the city :kolkata
# enter the age:40
# enter account type :s
# enter intial amount :10000
# enter the account no12
#
#  -----Account created Successfully----
#
# 		1.New Customer
# 		2.Existing Customer
# 		3.Exit
#         Enter choice :2
# enter account number12
#
# -------Account Exists--------
# 		-----User Portal------
#
# 1.check Balance
# 2.Withdrwa
# 3.Deposit
# 4.Back to main menu
#
# Enter choice:1
# your avaliable balance: 10000
# 		-----User Portal------
#
# 1.check Balance
# 2.Withdrwa
# 3.Deposit
# 4.Back to main menu
#
# Enter choice:3
# enter the amount to be deposited :4000
#
# -----Amount deposited-----
# 		-----User Portal------
#
# 1.check Balance
# 2.Withdrwa
# 3.Deposit
# 4.Back to main menu
#
# Enter choice:1
# your avaliable balance: 14000
# 		-----User Portal------
#
# 1.check Balance
# 2.Withdrwa
# 3.Deposit
# 4.Back to main menu
#
# Enter choice:2
# enter the amount to be Withdraw :20000
# Amount Withdrawn
# 		-----User Portal------
#
# 1.check Balance
# 2.Withdrwa
# 3.Deposit
# 4.Back to main menu
#
# Enter choice:1
# your avaliable balance: -6000
# 		-----User Portal------
#
# 1.check Balance
# 2.Withdrwa
# 3.Deposit
# 4.Back to main menu
#
# Enter choice:4
#
# 		1.New Customer
# 		2.Existing Customer
# 		3.Exit
#         Enter choice :3
