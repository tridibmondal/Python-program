# %%
import pandas as pd

# %%
weather=pd.read_csv("E:\\datasets\\weather.csv")

# %%
weather
# Out:
#            date  maximum temperature  minimum temperature  \
# 0    01-01-2016                 42.0                   34
# 1    02-01-2016                 40.0                   32
# 2    03-01-2016                 45.0                   35
# 3    04-01-2016                 36.0                   14
# 4    05-01-2016                 29.0                   11
# 5    06-01-2016                 41.0                   25
# 6    07-01-2016                 46.0                   31
# 7    08-01-2016                 46.0                   31
# 8    09-01-2016                  NaN                   40
# 9    10-01-2016                 59.0                   40
# 10   11-01-2016                 40.0                   26
# 11   12-01-2016                 44.0                   25
# 12   13-01-2016                 30.0                   22
# 13   14-01-2016                 38.0                   22
# 14   15-01-2016                 51.0                   34
# ...

# %%
import matplotlib.pyplot as plt

# %%
x=weather.iloc[:10,0]

# %%
y=weather.iloc[:10,1]

# %%
plt.plot(x,y)

# %%
weather.isnull().sum()
# Out:
# date                   0
# maximum temperature    3
# minimum temperature    0
# average temperature    0
# precipitation          0
# snow fall              1
# snow depth             1
# dtype: int64

# %%
weather['maximum temperature'].fillna(method="ffill",inplace=True)

# %%
weather.isnull().sum()
# Out:
# date                   0
# maximum temperature    0
# minimum temperature    0
# average temperature    0
# precipitation          0
# snow fall              1
# snow depth             1
# dtype: int64

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y,c="red",marker="*")

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.hist(y)
# Out:
# (array([1., 0., 1., 1., 2., 4., 0., 0., 0., 1.]),
#  array([29., 32., 35., 38., 41., 44., 47., 50., 53., 56., 59.]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns

# %%
sns.countplot(x='maximum temperature',data=weather)
plt.show()

# %%
sns.countplot(x='maximum temperature',data=weather.iloc[:10])
plt.show()

# %%
sns.pairplot(weather)
plt.show()
